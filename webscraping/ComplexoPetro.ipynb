# %%
import os
import sys
import pandas as pd
import pickle
import string  
import numpy as np

# %%
#Importando o conjunto de dados
df_areas = pd.read_excel('labs_mcti2.xlsx' , sheet_name='areas_labs')

# %%
df_areas.head()
# Out:
#                                     site_mcti    lab  \
# 0  https://pnipe.mcti.gov.br/laboratory/10006  10006
# 1  https://pnipe.mcti.gov.br/laboratory/10006  10006
# 2  https://pnipe.mcti.gov.br/laboratory/10006  10006
# 3  https://pnipe.mcti.gov.br/laboratory/10006  10006
# 4  https://pnipe.mcti.gov.br/laboratory/10006  10006
#
#                            areas
# 0                       Genômica
# 1                     Proteômica
# 2                    Epigenômica
# 3  sequenciador Miseq (Illumina)
# 4                        Luminex

# %%
df_areas.dtypes
# Out:
# site_mcti    object
# lab           int64
# areas        object
# dtype: object

# %%
#https://zenodo.org/records/11185049

# %%
df_areas.groupby('areas').count()
# Out:
#                                                     site_mcti  lab
# areas
#  Análise térmica por TGA                                    5    5
#  Desenvolvimento de formulação                              4    4
#  Destilação Atmosférica (Baseado na ASTM D2892)             1    1
#  Detecção de processos de relaxação moleculares             1    1
#  Espectrofotômetro UV-VIS                                   7    7
# ...                                                       ...  ...
# ●\tTestes in vivo - cicatrização, gastroproteçã...          1    1
# \tCaracterização de Sedimentos finos                       1    1
# \tHidrodinâmica de estuários                               2    2
# \tInfraestruturas marítimas de acesso portuári...          1    1
# \tPropagação de maré em águas rasas                        1    1
#
# [24825 rows x 2 columns]

# %%
import string  
import pandas as pd
import numpy as np


df_areas['Petro'] = np.where( df_areas['areas'].str.contains("Exploração Offshore", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Exploração Onshore", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Sísmica", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Perfuração Exploratória", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Blocos Exploratórios", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Margem Equatorial", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Bacias Sedimentares", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Destilação Atmosférica:", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Destilação a Vácuo", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Craqueamento Catalítico", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Hidrotratamento", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Reforma Catalítica:", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Alquilação", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Isomerização", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Desasfaltação", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Petróleo", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("petroquímica", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Gás natural", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Petróleo", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Petrobras", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Gasolina", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Perfuração Rotativa", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Perfuração Direcional", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Perfuração Horizontal", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Perfuração Offshore", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Perfuração Onshore", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Perfuração de Desenvolvimento", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Perfuração Onshore", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Reservatórios de Óleo", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Reservatórios de Gás", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Rochas-Reservatório", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Armadilhas de Petróleo", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Injeção de Água", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Recuperação Aprimorada", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Gasolina", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("Pré-Sal", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("Bacia de Campos", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("Bacia de Santos", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("Engenharia Submarina", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("Diesel", case=False, na=False), 1 ,
                    np.where( df_areas['areas'].str.contains("Desenvolvimento de Reservatórios", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("Segurança energetica", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("hidrocarbonetos", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("Querosene", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("Metano", case=False, na=False), 1 ,  
                    np.where( df_areas['areas'].str.contains("Segurança energetica", case=False, na=False), 1 ,                                                                              
                    np.where( df_areas['areas'].str.contains("Perfuração de Avaliação", case=False, na=False), 1 , 0 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )   



#Reservatórios de Óleo: Estruturas geológicas que armazenam hidrocarbonetos no estado líquido1.
#Reservatórios de Gás: Estruturas geológicas que armazenam hidrocarbonetos no estado gasoso1.
#Rochas-Reservatório: Rochas porosas e permeáveis que permitem o armazenamento de petróleo em volumes significativos2.
#Armadilhas de Petróleo: Estruturas geológicas que impedem a migração do petróleo, como anticlinais, falhas geológicas e domos salinos2.
#Injeção de Água: Técnica utilizada para manter a pressão e a mobilidade do petróleo dentro dos reservatórios3.
#Recuperação Aprimorada (EOR): Métodos para aumentar a eficiência da extração de petróleo dos reservatórios3.
#Perfuração Rotativa: Técnica que utiliza uma broca giratória para romper as rochas1.
#Perfuração Direcional: Técnica que permite desviar o furo de sua trajetória vertical para acessar múltiplos reservatórios a partir de um único ponto2.
#Perfuração Horizontal: Técnica que estende os poços lateralmente através dos reservatórios, aumentando a eficiência da extração1.
#Perfuração Offshore: Perfuração realizada em plataformas marítimas para acessar reservas submarinas2.
#Perfuração Onshore: Perfuração realizada em terra firme para acessar reservas subterrâneas2.
#Perfuração de Desenvolvimento: Perfuração de poços adicionais em um campo já descoberto para otimizar a produção2.
#Perfuração de Avaliação: Perfuração de poços para avaliar a extensão e a qualidade de uma descoberta de petróleo ou gás2.
#Exploração Offshore: Busca por reservas de petróleo e gás em áreas marítimas.
#Exploração Onshore: Busca por reservas de petróleo e gás em áreas terrestres.
#Sísmica: Técnica de levantamento geofísico para mapear estruturas subterrâneas.
#Perfuração Exploratória: Perfuração de poços para descobrir novas reservas.
#Blocos Exploratórios: Áreas designadas para exploração de petróleo e gás.
#Margem Equatorial: Nova fronteira exploratória no Brasil, especialmente no norte do país1.
#Bacias Sedimentares: Regiões geológicas onde se acumulam sedimentos que podem conter petróleo e gás.
#Destilação Atmosférica: Processo inicial de separação dos componentes do petróleo bruto.
#Destilação a Vácuo: Técnica para refinar frações mais pesadas do petróleo.
#Craqueamento Catalítico: Processo que quebra moléculas maiores em menores, produzindo gasolina e outros produtos leves.
#Hidrotratamento: Remoção de impurezas como enxofre e nitrogênio dos produtos refinados.
#Reforma Catalítica: Processo que aumenta o número de octanas na gasolina.
#Alquilação: Produção de componentes de alta octanagem para gasolina.
#Coking: Conversão de resíduos pesados em produtos mais leves e coque de petróleo.
#Isomerização: Conversão de hidrocarbonetos para melhorar a qualidade da gasolina.
#Desasfaltação: Separação de asfaltenos do petróleo para melhorar a qualidade dos produtos refinados.

# %%
df_areas.groupby(['Petro']).count()
# Out:
#        site_mcti    lab  areas
# Petro
# 0          64334  64334  64292
# 1            250    250    250

# %%
len(df_areas['lab'][df_areas['Petro']==1].unique())
# Out:
# 174

# %% [markdown]
# ## Unificando Dados da FAPESP

# %%
#Importando o conjunto de dados
df_nomes = pd.read_excel('labs_mcti2.xlsx' , sheet_name='cadatro_nomes')

# %%
df_nomes.shape
# Out:
# (6323, 13)

# %%
df_nomes.head()
# Out:
#      lab                                   site_mcti  \
# 0  10006  https://pnipe.mcti.gov.br/laboratory/10006
# 1  10008  https://pnipe.mcti.gov.br/laboratory/10008
# 2  10037  https://pnipe.mcti.gov.br/laboratory/10037
# 3   1004   https://pnipe.mcti.gov.br/laboratory/1004
# 4  10057  https://pnipe.mcti.gov.br/laboratory/10057
#
#                                             nome_lab data_de_criacao  \
# 0                 CTO - Centro de Tecnologias Ômicas      17/03/2022
# 1  NB3 - Laboratório Multiusuário com Nivel de Bi...      17/03/2022
# 2  IA BMF - ICB/USP - Instalação Animal do Depart...      18/03/2022
# 3              Mietto Lab - Lab. de Biologia Celular      22/09/2020
# 4  QA/SECTEC/LAPOC - Laboratório de Radiometria e...      21/03/2022
#
#                                   universidade           nome_responsavel  \
# 0              USP - Universidade de São Paulo      Mario Hiroyuki Hirata
# 1              USP - Universidade de São Paulo      Mario Hiroyuki Hirata
# ...

# %%
len(df_areas['lab'][df_areas['Petro']==1].unique())

# %%
df_nomes[df_nomes['lab'].isin(df_areas['lab'][df_areas['Petro']==1].unique())].head()
# Out:
#        lab                                   site_mcti  \
# 11   10117  https://pnipe.mcti.gov.br/laboratory/10117
# 260   1148   https://pnipe.mcti.gov.br/laboratory/1148
# 309  11647  https://pnipe.mcti.gov.br/laboratory/11647
# 363  11836  https://pnipe.mcti.gov.br/laboratory/11836
# 364  11842  https://pnipe.mcti.gov.br/laboratory/11842
#
#                                               nome_lab data_de_criacao  \
# 11           LATAB - Laboratório de Tabaco e Derivados      28/03/2022
# 260  LABRMN-L - Laboratório Multiusuário de Ressonâ...      24/09/2020
# 309  LAPROMAQ - Laboratório de Proteínas e Microrga...      12/08/2022
# 363      PROCAT - Laboratório de Processos Catalíticos      23/08/2022
# 364  LABMATER - Laboratório de Materiais e Energias...      23/08/2022
#
#                                           universidade   nome_responsavel  \
# 11              INT - Instituto Nacional de Tecnologia   SIMONE CHIAPETTA
# ...

# %%
df_nomes['Petro'] = np.where( df_nomes['sobre'].str.contains("Exploração Offshore", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Exploração Onshore", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Sísmica", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Perfuração Exploratória", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Blocos Exploratórios", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Margem Equatorial", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Bacias Sedimentares", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Destilação Atmosférica:", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Destilação a Vácuo", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Craqueamento Catalítico", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Hidrotratamento", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Reforma Catalítica:", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Alquilação", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Isomerização", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Desasfaltação", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Petróleo", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("petroquímica", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Gás natural", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Petróleo", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Petrobras", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Gasolina", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Perfuração Rotativa", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Perfuração Direcional", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Perfuração Horizontal", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Perfuração Offshore", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Perfuração Onshore", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Perfuração de Desenvolvimento", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Perfuração Onshore", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Reservatórios de Óleo", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Reservatórios de Gás", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Rochas-Reservatório", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Armadilhas de Petróleo", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Injeção de Água", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Recuperação Aprimorada", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Gasolina", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("Pré-Sal", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("Bacia de Campos", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("Bacia de Santos", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("Engenharia Submarina", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("Diesel", case=False, na=False), 1 ,
                    np.where( df_nomes['sobre'].str.contains("Desenvolvimento de Reservatórios", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("Segurança energetica", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("hidrocarbonetos", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("Querosene", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("Metano", case=False, na=False), 1 ,  
                    np.where( df_nomes['sobre'].str.contains("Segurança energetica", case=False, na=False), 1 ,                                                                              
                    np.where( df_nomes['sobre'].str.contains("Perfuração de Avaliação", case=False, na=False), 1 , 0 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )

# %%
# Estudar esse site
# https://huyenchip.com/2024/07/25/genai-platform.html

# %%
df_nomes_petro = df_nomes[ (df_nomes['lab'].isin(df_areas['lab'][df_areas['Petro']==1].unique())) |
                           (df_nomes['Petro']==1 )].copy()

# %%
df_nomes_petro.shape
# Out:
# (250, 14)

# %%
df_areas_petro = df_areas[ (df_areas['lab'].isin(df_nomes['lab'][df_nomes['Petro']==1].unique())) |
                           (df_areas['Petro']==1 )].copy()

# %%
df_areas_petro.shape
# Out:
# (1786, 4)

# %%
#Importando o conjunto de dados
df_equip = pd.read_excel('labs_mcti2.xlsx' , sheet_name='codigos_equip')

# %%
df_equip.dtypes
# Out:
# site_mcti    object
# lab           int64
# codigos      object
# dtype: object

# %%
#codigos_equip
df_equip_petro = df_equip[ (df_equip['lab'].isin(df_nomes['lab'][df_nomes['Petro']==1].unique())) |
                           (df_equip['lab'].isin(df_areas['lab'][df_areas['Petro']==1].unique())) ].copy()

# %%
df_equip_petro.shape
# Out:
# (1268, 3)

# %%
df_nomes_petro.to_excel('labs_mcti_petro1.xlsx',sheet_name='cadatro_nomes')
df_areas_petro.to_excel('labs_mcti_petro2.xlsx',sheet_name='areas_labs')
df_equip_petro.to_excel('labs_mcti_petro3.xlsx',sheet_name='codigos_equip')

# %%
# https://pystoned.readthedocs.io/en/latest/examples/DEA/dea_ddf.html
# https://pystoned.readthedocs.io/en/latest/examples/StoNED/mom.html
