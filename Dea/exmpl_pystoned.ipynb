# %% [markdown]
# # Instalacão
# https://pystoned.readthedocs.io/en/latest/install/index.html

# %%
#! pip install pystoned
#! pip install -U git+https://github.com/ds2010/pyStoNED

# %% [markdown]
# # Example: StoNED with CNLS [.ipynb]
# - #https://pystoned.readthedocs.io/en/latest/examples/StoNED/mom.html

# %%
# import packages
from pystoned import CNLS, StoNED
from pystoned.dataset import load_Finnish_electricity_firm
from pystoned.constant import CET_MULT, FUN_COST, RTS_VRS, RED_MOM

# %%
# import Finnish electricity distribution firms data
data = load_Finnish_electricity_firm(x_select=['Energy', 'Length', 'Customers'],
                                    y_select=['TOTEX'])

# build and optimize the CNLS model
model = CNLS.CNLS(data.y, data.x, z=None, cet=CET_MULT, fun=FUN_COST, rts=RTS_VRS)
model.optimize('patrickfrancoalves@yahoo.com.br')
# Out:
# Estimating the multiplicative model remotely with knitro solver.

# %%
# calculate and print unconditional expected inefficiency (mu)
rd = StoNED.StoNED(model)

print(rd.get_unconditional_expected_inefficiency(RED_MOM))
# Out:
# 0.028561358246550088

# %%
model.get_frontier()
# Out:
# array([  1551.47064088,   1610.03242581,   1429.13889375,  17984.10286582,
#          1013.57472198,   3736.99520342,   1339.76206396,   3034.84848468,
#           985.76554169,   2533.52651321,  28717.26232382, 120434.31110995,
#          1541.37015649,   2111.46300066,  49577.97060335,   5970.68397409,
#           940.55111616,   1132.45845592,   1686.43097772,   4884.2142589 ,
#          3327.14650317,   2937.76230269,    375.51362128,   6784.39159468,
#          1277.05329222,   1826.54728312,   1548.69140299,  33521.95130992,
#          1174.11485896,   2609.9736047 ,   1395.48721768,   4315.78232444,
#          4005.29463393,   2709.85463753,   2481.4343192 ,   4675.79922654,
#          5146.70268573,   1652.77598661,   1041.92472033,   7987.1299044 ,
#          7217.70091868,    879.96869836,  23291.64705106,   1640.42963615,
#          1720.90222591,   1396.6355561 ,   9297.89324103,    699.05883791,
#          6677.94599697,  13617.29102871,   1003.32194426,   3944.45644585,
#          1330.08006195,   5097.1689904 ,   1453.78498154,  12657.21595245,
#          6553.15629488,   1998.17715709,   2600.65037195,   3521.697456  ,
#           413.18349195,  28815.14279834,   9763.24254649,   6860.27368596,
#          1370.59303956,   1393.68773172,   3228.52164981,   9793.48692938,
#          3463.45495926,   6631.69929659,  37269.72185795,   3432.96564365,
#         18955.7289649 ,   1102.49173123,   2266.3491935 ,   5041.58375506,
#         12561.68701657,    793.68733135,  12718.51278804,   6161.10870012,
#          2248.36638214,  14809.7948902 ,   5370.04948772, 107702.60392788,
#          5859.33005379,    665.89945373,    668.44238425,    575.66084837,
#          1692.08064442])

# %% [markdown]
# # Example: DEA with DDF [.ipynb]
# - https://pystoned.readthedocs.io/en/latest/examples/DEA/dea_ddf.html

# %%
# import packages
from pystoned import DEA
from pystoned import dataset as dataset
from pystoned.constant import RTS_VRS, OPT_LOCAL

# import the data provided with Tim Coelli’s Frontier 4.1
data = dataset.load_Tim_Coelli_frontier()

# define and solve the DEA DDF model
model = DEA.DDF(y=data.y, x=data.x, b=None, gy=[1], gx=[0.0, 0.0], gb=None, rts=RTS_VRS, yref=None, xref=None, bref=None)
model.optimize(OPT_LOCAL)

# display the technical efficiency
model.display_theta()

# display the intensity variables
model.display_lamda()
# Out:
# Optimizing locally.
# Estimating the additive model locally with mosek solver.
# MOSEK error 1008 (MSK_RES_ERR_MISSING_LICENSE_FILE): License cannot be located. The default search path is ';C:\Users\patrick.franco\mosek\mosek.lic;'.
#
# *** A FLEXlm error occurred. FLEXlm reported:
#
#
#
# *** end of FLEXlm report.
#
# ERROR: rescode.err_missing_license_file(1008): License cannot be located. The
# default search path is ';C:\Users\patrick.franco\mosek\mosek.lic;'.
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[8], line 11
#       9 # define and solve the DEA DDF model
#      10 model = DEA.DDF(y=data.y, x=data.x, b=None, gy=[1], gx=[0.0, 0.0], gb=None, rts=RTS_VRS, yref=None, xref=None, bref=None)
# ---> 11 model.optimize(OPT_LOCAL)
#      13 # display the technical efficiency
#      14 model.display_theta()
#
# File c:\Users\patrick.franco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pystoned\DEA.py:107, in DEA.optimize(self, email, solver)
#     100 """Optimize the function by requested method
#     101
#     102 Args:
#     103     email (string): The email address for remote optimization. It will optimize locally if OPT_LOCAL is given.
#     104     solver (string): The solver chosen for optimization. It will optimize with default solver if OPT_DEFAULT is given.
#     105 """
#     106 # TODO(error/warning handling): Check problem status after optimization
# --> 107 self.problem_status, self.optimization_status = tools.optimize_model(
#     108     self.__model__, email, CET_ADDI, solver)
#
# File c:\Users\patrick.franco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pystoned\utils\tools.py:57, in optimize_model(model, email, cet, solver)
#      54     solver_instance = SolverFactory(solver)
#      55     print("Estimating the {} locally with {} solver.".format(
#      56         CET_Model_Categories[cet], solver), flush=True)
# ---> 57     return solver_instance.solve(model, tee=True), 1
#      58 else:
#      59     if solver is OPT_DEFAULT and cet is CET_ADDI:
#
# File c:\Users\patrick.franco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyomo\solvers\plugins\solvers\direct_solver.py:142, in DirectSolver.solve(self, *args, **kwds)
#     139 if not _model is None:
#     140     self._initialize_callbacks(_model)
# --> 142 _status = self._apply_solver()
#     143 if hasattr(self, '_transformation_data'):
#     144     del self._transformation_data
#
# File c:\Users\patrick.franco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyomo\solvers\plugins\solvers\mosek_direct.py:184, in MOSEKDirect._apply_solver(self)
#     182         raise
#     183 try:
# --> 184     self._termcode = self._solver_model.optimize()
#     185     self._solver_model.solutionsummary(mosek.streamtype.msg)
#     186 except mosek.Error as e:
#     187     # MOSEK is not good about releasing licenses when an
#     188     # exception is raised during optimize().  We will explicitly
#     189     # release all licenses to prevent (among other things) a
#     190     # "license leak" during testing with expected failures.
#
# File c:\Users\patrick.franco\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosek\__init__.py:11416, in Task.optimize(self, *args, **kwds)
#   11409 def optimize(self,*args,**kwds):
#   11410   """
#   11411   Optimizes the problem.
#   11412
#   11413   optimize() -> (trmcode)
#   11414     [trmcode : mosek.rescode]  Is either OK or a termination response code.
#   11415   """
# > 11416   return self.__optimizetrm__1(*args,**kwds)
#
# File c:\Users\patrick.franco\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosek\__init__.py:11405, in Task.__optimizetrm__1(self)
#   11403 if _res_optimizetrm != 0:
#   11404   _,_msg_optimizetrm = self.__getlasterror(_res_optimizetrm)
# > 11405   raise Error(rescode(_res_optimizetrm),_msg_optimizetrm)
#   11406 else:
#   11407   (trmcode) = _retargs_optimizetrm
#
# Error: rescode.err_missing_license_file(1008): License cannot be located. The default search path is ';C:\Users\patrick.franco\mosek\mosek.lic;'.

# %%
# import packages
from pystoned import CNLS, StoNED
from pystoned.dataset import load_Finnish_electricity_firm
from pystoned.constant import CET_MULT, FUN_COST, RTS_VRS, RED_KDE

# import Finnish electricity distribution firms data
data = load_Finnish_electricity_firm(x_select=['Energy', 'Length', 'Customers'],
                                     y_select=['TOTEX'])

# build and optimize the CNLS model
model = CNLS.CNLS(data.y, data.x, z=None, cet=CET_MULT, fun=FUN_COST, rts=RTS_VRS)
model.optimize('patrickfrancoalves@yahoo.com.br')

# calculate and print unconditional expected inefficiency (mu)
rd = StoNED.StoNED(model)
print(rd.get_unconditional_expected_inefficiency(RED_KDE))
# Out:
# Estimating the multiplicative model remotely with knitro solver.
# 3.1926861359978393

# %%
# import packages
from pystoned import CNLS, StoNED
from pystoned.dataset import load_Finnish_electricity_firm
from pystoned.constant import CET_MULT, FUN_COST, RTS_VRS, RED_MOM

# import Finnish electricity distribution firms data
data = load_Finnish_electricity_firm(x_select=['Energy', 'Length', 'Customers'],
                                    y_select=['TOTEX'])

# build and optimize the CNLS model
model = CNLS.CNLS(data.y, data.x, z=None, cet=CET_MULT, fun=FUN_COST, rts=RTS_VRS)
model.optimize('patrickfrancoalves@yahoo.com.br')

# calculate and print the StoNED frontier
rd = StoNED.StoNED(model)
print(rd.get_stoned(RED_MOM))
# Out:
# Estimating the multiplicative model remotely with knitro solver.
# [  1670.39203593   1688.46841117   1581.28367059  18028.85906773
#     984.97632613   4264.75269807   1396.95328587   3273.1844943
#    1010.91784739   2789.69661053  29957.76002811 117046.22830683
#    1734.08817123   2324.60900879  48168.23307781   6204.21724918
#    1032.76058108   1256.09248336   1778.4720697    5277.13275772
#    3351.15744434   3286.00454276    364.93957744   7048.38779837
#    1355.94998071   1987.69808008   1673.61356238  32545.06161952
#    1140.84663095   2811.28893177   1528.20325645   4193.23639567
#    4468.28071311   2828.64281762   2622.63527729   4637.97432812
#    5169.88913367   1781.43800431   1118.30686779   8552.45294551
#    7013.66045962    893.1849563   24491.24503954   1788.03706776
#    1904.00174758   1357.17459566   9836.14925466    685.33681346
#    7098.22295213  15155.95170209   1049.69523896   4202.91310728
#    1480.72181353   5551.55122268   1571.60644628  14134.60462511
#    7084.35778889   2141.05267915   2793.53661706   3543.60729838
#     411.18754314  28385.6684618   10716.13578279   7412.76567039
#    1482.82802922   1464.07840272   3596.37624716   9835.91770671
#    3832.40694033   6975.02975882  36204.72610461   3895.31918413
#   21447.80836592   1147.56680556   2525.63357891   5054.80081847
#   13846.04569265    771.28336953  13763.68977863   6557.76151777
#    2479.08411188  16722.19674393   5546.58014676 104668.09873517
#    6184.68418864    724.5509697     726.09499791    559.41589125
#    1840.8826352 ]

# %%
data.y
# Out:
# array([[  1612],
#        [  1659],
#        [  1708],
#        [ 18918],
#        [  1167],
#        [  3395],
#        [  1333],
#        [  3518],
#        [  1415],
#        [  2469],
#        [ 28750],
#        [117554],
#        [  1925],
#        [  2747],
#        [ 48605],
#        [  5486],
#        [  1091],
#        [  1297],
#        [  1691],
#        [  4605],
#        [  3102],
#        [  2260],
#        [   341],
#        [  6100],
#        [  1440],
#        [  1958],
#        [  1976],
#        [ 29722],
#        [  1254],
#        [  2665],
#        [  1376],
#        [  3121],
#        [  3864],
#        [  3221],
#        [  2561],
#        [  5779],
#        [  4380],
#        [  1423],
#        [   907],
#        [  7915],
#        [  6639],
#        [   868],
#        [ 25556],
#        [  1540],
#        [  1564],
#        [  1229],
#        [  9807],
#        [   669],
#        [  6097],
#        [ 12154],
#        [  1186],
#        [  4020],
#        [  1589],
#        [  6414],
#        [  1515],
#        [ 10600],
#        [  5431],
#        [  1872],
#        [  2206],
#        [  3767],
#        [   268],
#        [ 28295],
#        [  9689],
#        [  7226],
#        [  1871],
#        [  1280],
#        [  3539],
#        [  9853],
#        [  3758],
#        [  5499],
#        [ 37368],
#        [  3735],
#        [ 16141],
#        [   987],
#        [  2067],
#        [  5105],
#        [ 12687],
#        [   861],
#        [ 12831],
#        [  6055],
#        [  2156],
#        [ 13794],
#        [  5054],
#        [108310],
#        [  6162],
#        [   594],
#        [   672],
#        [   616],
#        [  1776]], dtype=int64)

# %% [markdown]
# # Calculating firm-level efficiency
# - Example: Using StoNED with CNLSG [.ipynb]¶

# %%
# import packages
from pystoned import CNLSG, StoNED
from pystoned.dataset import load_Finnish_electricity_firm
from pystoned.constant import CET_MULT, FUN_COST, RTS_VRS, RED_MOM

# import Finnish electricity distribution firms data
data = load_Finnish_electricity_firm(x_select=['Energy', 'Length', 'Customers'],
                                    y_select=['TOTEX'])

# build and optimize the CNLS model
model = CNLSG.CNLSG(data.y, data.x, z=None, cet=CET_MULT, fun=FUN_COST, rts=RTS_VRS)
model.optimize('email@address')

# Calculate firm-level efficiency
rd = StoNED.StoNED(model)
print(rd.get_technical_inefficiency(RED_MOM))
# Out:
# array([[  1612],
#        [  1659],
#        [  1708],
#        [ 18918],
#        [  1167],
#        [  3395],
#        [  1333],
#        [  3518],
#        [  1415],
#        [  2469],
#        [ 28750],
#        [117554],
#        [  1925],
#        [  2747],
#        [ 48605],
#        [  5486],
#        [  1091],
#        [  1297],
#        [  1691],
#        [  4605],
#        [  3102],
#        [  2260],
#        [   341],
#        [  6100],
#        [  1440],
#        [  1958],
#        [  1976],
#        [ 29722],
#        [  1254],
#        [  2665],
#        [  1376],
#        [  3121],
#        [  3864],
#        [  3221],
#        [  2561],
#        [  5779],
#        [  4380],
#        [  1423],
#        [   907],
#        [  7915],
#        [  6639],
#        [   868],
#        [ 25556],
#        [  1540],
#        [  1564],
#        [  1229],
#        [  9807],
#        [   669],
#        [  6097],
#        [ 12154],
#        [  1186],
#        [  4020],
#        [  1589],
#        [  6414],
#        [  1515],
#        [ 10600],
#        [  5431],
#        [  1872],
#        [  2206],
#        [  3767],
#        [   268],
#        [ 28295],
#        [  9689],
#        [  7226],
#        [  1871],
#        [  1280],
#        [  3539],
#        [  9853],
#        [  3758],
#        [  5499],
#        [ 37368],
#        [  3735],
#        [ 16141],
#        [   987],
#        [  2067],
#        [  5105],
#        [ 12687],
#        [   861],
#        [ 12831],
#        [  6055],
#        [  2156],
#        [ 13794],
#        [  5054],
#        [108310],
#        [  6162],
#        [   594],
#        [   672],
#        [   616],
#        [  1776]], dtype=int64)
